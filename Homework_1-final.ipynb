# %% [markdown]
# <a href="https://colab.research.google.com/github/Didinetech/IMC2023-Portelus/blob/main/Homework_1-final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import numpy as np
import matplotlib.pylab as plt
import librosa
import librosa.display
#import audio files
# !git clone https://github.com/jcdevaney/imc2023.git
# Out:
# fatal: destination path 'imc2023' already exists and is not an empty directory.

# %%
def readAudioFunction(file, samplingRate):
    # remember that you only need to use plt.plot() once

    # open the audio file avm2.wav with librosa.load()
    sig, sr = librosa.load(file,mono=True,sr=samplingRate)
    # adjust the x-axis to represent time
    time=np.arange(0,sig.shape[0])/sr
    plt.plot(time,sig)
    # scale the y-axis to represent amplitude
    excursion=max(abs(sig))
    sigNew = sig / excursion
    plt.plot(time,sigNew)
    # label the x and y axes
    plt.plot(time,sigNew)
    plt.xlabel('Time (seconds)')
    plt.ylabel('Amplitude')

# %%
file = 'imc2023/audioFiles/avm.wav'
samplingRate = 44100
readAudioFunction(file, samplingRate)

# %%
  # open the audio file avm.wav with librosa.load()
  file = 'imc2023/audioFiles/avm.wav'
  samplingRate = 441
  readAudioFunction(file, samplingRate)
